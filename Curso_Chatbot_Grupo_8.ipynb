# %% [markdown]
# <a href="https://colab.research.google.com/github/davidhsv/cursochatbot/blob/master/Curso_Chatbot_Grupo_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/davidhsv/cursochatbot.git
# %cd cursochatbot
# !pip install -r requirements.txt

# !rasa train
# Out:
# Cloning into 'cursochatbot'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 52 (delta 16), reused 39 (delta 6), pack-reused 0
# Unpacking objects: 100% (52/52), done.
# /content/cursochatbot
# ...
#      |████████████████████████████████| 522kB 5.1MB/s
# ...
#      |████████████████████████████████| 112kB 24.6MB/s
# ...
#      |████████████████████████████████| 1.2MB 19.8MB/s
# ...
#      |████████████████████████████████| 61kB 9.1MB/s
# ...
#      |████████████████████████████████| 133kB 32.5MB/s
# ...
#      |████████████████████████████████| 6.7MB 27.2MB/s
# ...
#      |████████████████████████████████| 51kB 8.1MB/s
# ...
#      |████████████████████████████████| 2.6MB 52.7MB/s
# ...
#      |████████████████████████████████| 194kB 46.9MB/s
# ...
#      |████████████████████████████████| 829kB 51.6MB/s
# ...
#      |████████████████████████████████| 5.1MB 49.5MB/s
# ...
#      |████████████████████████████████| 122kB 55.8MB/s
# ...

# %%
# %doctest_mode
# Out:
# Exception reporting mode: Plain
# Doctest mode is: ON

# %%
# !rasa shell
# Out:
# 2020-10-14 22:10:14 INFO     root  - Connecting to channel 'cmdline' which was specified by the '--connector' argument. Any other channels will be ignored. To connect to all given channels, omit the '--connector' argument.
# 2020-10-14 22:10:14 INFO     root  - Starting Rasa server on http://localhost:5005
# 2020-10-14 22:10:19 INFO     root  - Rasa server is up and running.
# Bot loaded. Type a message and press enter (use '/stop' to exit):
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Oi, eu sou um bot, um assistente virtual!
# Uhuu! Manda aí um assunto que te interessa :)
# Para aprender como você pode interagir comigo basta escrever meajuda.
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Oi, eu sou um bot, um assistente virtual!
# Uhuu! Manda aí um assunto que te interessa :)
# Para aprender como você pode interagir comigo basta escrever meajuda.
# WARNING: your terminal doesn't support cursor position requests (CPR).
