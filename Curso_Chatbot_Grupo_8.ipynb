# %% [markdown]
# <a href="https://colab.research.google.com/github/davidhsv/cursochatbot/blob/master/Curso_Chatbot_Grupo_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/davidhsv/cursochatbot.git
# %cd cursochatbot
# !pip install -r requirements.txt
# !pip install nest_asyncio
# !pip install tornado>=6.0.3

# !rasa train

# %%
# !rasa shell

# %%
from rasa.core.agent import Agent

ultimo_model = !ls /content/cursochatbot/models/ -Art | tail -n 1
agent = Agent.load(model_path="/content/cursochatbot/models/" + ultimo_model[0])
import nest_asyncio

nest_asyncio.apply()
print("Event loop ready.")

import asyncio

loop = asyncio.get_event_loop()

print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = loop.run_until_complete(agent.handle_text(a))
    for response in responses:
      print(response['text'])
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method FBetaScore.update_state of <tensorflow_addons.metrics.f_scores.F1Score object at 0x7ff55a519f60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method FBetaScore.update_state of <tensorflow_addons.metrics.f_scores.F1Score object at 0x7ff55a519f60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DIET.batch_predict of <rasa.nlu.classifiers.diet_classifier.DIET object at 0x7ff55a3dab00>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method DIET.batch_predict of <rasa.nlu.classifiers.diet_classifier.DIET object at 0x7ff55a3dab00>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseForSparse.call of <rasa.utils.tensorflow.layers.DenseForSparse object at 0x7ff55a7f1710>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method DenseForSparse.call of <rasa.utils.tensorflow.layers.DenseForSparse object at 0x7ff55a7f1710>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method Ffnn.call of <rasa.utils.tensorflow.layers.Ffnn object at 0x7ff55a3bc278>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method Ffnn.call of <rasa.utils.tensorflow.layers.Ffnn object at 0x7ff55a3bc278>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method TransformerEncoder.call of <rasa.utils.tensorflow.transformer.TransformerEncoder object at 0x7ff55a3bc9e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method TransformerEncoder.call of <rasa.utils.tensorflow.transformer.TransformerEncoder object at 0x7ff55a3bc9e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a3bcd30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a3bcd30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method TransformerEncoderLayer.call of <rasa.utils.tensorflow.transformer.TransformerEncoderLayer object at 0x7ff55a4109e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method TransformerEncoderLayer.call of <rasa.utils.tensorflow.transformer.TransformerEncoderLayer object at 0x7ff55a4109e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method MultiHeadAttention.call of <rasa.utils.tensorflow.transformer.MultiHeadAttention object at 0x7ff55a410b70>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method MultiHeadAttention.call of <rasa.utils.tensorflow.transformer.MultiHeadAttention object at 0x7ff55a410b70>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a410f60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a410f60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a42dc88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a42dc88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a42dbe0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a42dbe0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a42d048>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a42d048>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56f814588>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56f814588>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56f814860>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56f814860>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method TransformerEncoderLayer.call of <rasa.utils.tensorflow.transformer.TransformerEncoderLayer object at 0x7ff56f814d30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method TransformerEncoderLayer.call of <rasa.utils.tensorflow.transformer.TransformerEncoderLayer object at 0x7ff56f814d30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method MultiHeadAttention.call of <rasa.utils.tensorflow.transformer.MultiHeadAttention object at 0x7ff5581886d8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method MultiHeadAttention.call of <rasa.utils.tensorflow.transformer.MultiHeadAttention object at 0x7ff5581886d8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff558188630>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff558188630>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff558188f60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff558188f60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff5581930b8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff5581930b8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff5621bf198>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff5621bf198>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff5621bf4a8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff5621bf4a8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56fa4e278>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56fa4e278>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method Ffnn.call of <rasa.utils.tensorflow.layers.Ffnn object at 0x7ff56fa75be0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method Ffnn.call of <rasa.utils.tensorflow.layers.Ffnn object at 0x7ff56fa75be0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff56fa752e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff56fa752e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff56fa75860>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff56fa75860>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff551c852e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff551c852e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method CRF.call of <rasa.utils.tensorflow.layers.CRF object at 0x7ff5621924e0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method CRF.call of <rasa.utils.tensorflow.layers.CRF object at 0x7ff5621924e0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method TED.batch_predict of <rasa.core.policies.ted_policy.TED object at 0x7ff55a3da320>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method TED.batch_predict of <rasa.core.policies.ted_policy.TED object at 0x7ff55a3da320>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method Ffnn.call of <rasa.utils.tensorflow.layers.Ffnn object at 0x7ff55a44e9e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method Ffnn.call of <rasa.utils.tensorflow.layers.Ffnn object at 0x7ff55a44e9e8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method TransformerEncoder.call of <rasa.utils.tensorflow.transformer.TransformerEncoder object at 0x7ff55a44eba8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method TransformerEncoder.call of <rasa.utils.tensorflow.transformer.TransformerEncoder object at 0x7ff55a44eba8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a463da0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a463da0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method TransformerEncoderLayer.call of <rasa.utils.tensorflow.transformer.TransformerEncoderLayer object at 0x7ff55a51e320>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method TransformerEncoderLayer.call of <rasa.utils.tensorflow.transformer.TransformerEncoderLayer object at 0x7ff55a51e320>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method MultiHeadAttention.call of <rasa.utils.tensorflow.transformer.MultiHeadAttention object at 0x7ff56f9f9978>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING: AutoGraph could not transform <bound method MultiHeadAttention.call of <rasa.utils.tensorflow.transformer.MultiHeadAttention object at 0x7ff56f9f9978>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a3d7748>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a3d7748>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a419c88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a419c88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a419160>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a419160>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56f910940>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff56f910940>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a955908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a955908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a955eb8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method DenseWithSparseWeights.call of <rasa.utils.tensorflow.layers.DenseWithSparseWeights object at 0x7ff55a955eb8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff55a955080>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method Embed.call of <rasa.utils.tensorflow.layers.Embed object at 0x7ff55a955080>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# Event loop ready.
# Your bot is ready to talk! Type your messages here or send 'stop'
# olá
# Oi, eu sou um bot, um assistente virtual!
# Uhuu! Manda aí um assunto que te interessa :)
# Para aprender como você pode interagir comigo basta escrever meajuda.
